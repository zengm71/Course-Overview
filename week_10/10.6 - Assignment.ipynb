# %% [markdown]
# In this assignment you will review some of the concepts from the class.

# %% [markdown]
# ## List, Mapping, Filtering, and Reducing Comprehensions
#
# Write a function and a list comprehension that doubles an integer or floating type values, reverses the content if it is a string, and does nothing if it is another kind of value.

# %%
fix_me = ['arsenic', 5, 'ball', 2, 47, 123, 'comprehensions', 'list', 5.5, 8343.23, 'shishkabob', None]

# %% [markdown]
# Now do the same with a map.

# %% [markdown]
# Now do the same, except filter out the final values that are less than 5. See if you can do it using only lambda expressions.

# %% [markdown]
# # Generating Random Data and Filtering That Data
#
# In this next section, we will work with NumPy. Set your random seed below in the way that I have.

# %%
import numpy as np
np.random.seed(25)
ar = np.random.randn(1000)

# %% [markdown]
# Now we will start playing around with this data. You will follow a series of steps and output your answers. For each step, you will use the `ar` value that I created above, and after each step, you should set `ar` to be the new `ar` value. The first step is:
#
# **Multiply all values by 100**
#
# so your answer will be the following.

# %%
ar = ar * 100
ar
# Out:
# array([  2.28273090e+01,   1.02689030e+02,  -8.39584849e+01,
#         -5.91181518e+01,  -9.56888297e+01,  -2.22325694e+01,
#         -6.19915108e+01,   1.83790458e+02,  -2.05323076e+02,
#          8.68583052e+01,  -9.20734440e+01,  -2.32311864e+01,
#          2.15295690e+02,  -1.33466147e+02,   7.63796505e+00,
#         -1.24608928e+02,   1.20227231e+02,  -1.04994158e+02,
#          1.05661011e+02,  -4.19677671e+01,   2.29484234e+02,
#         -2.59448738e+02,   2.82275640e+02,   6.80888923e+01,
#         -1.57769345e+02,  -1.97625359e+02,   5.33339823e+01,
#         -2.90869712e+01,  -5.13519669e+01,   1.98262608e+02,
#          2.26001050e+01,  -1.83990496e+02,   1.60767083e+02,
#          3.88291936e+01,   3.99732064e+01,   4.05476600e+01,
#          2.17001772e+01,  -6.33439103e+01,   2.46621529e+01,
#         -1.93954552e+02,   1.14059633e+01,  -1.88534140e+02,
#          2.43080482e+01,  -7.05480672e+01,   3.64627615e+01,
# ...

# %% [markdown]
# *the first 3 values should be*
#
# ```
# 2.28273090e+01,   1.02689030e+02,  -8.39584849e+01,
# ```

# %% [markdown]
# Now convert that matrix into a matrix of 8-bit integers.

# %% [markdown]
# *the first 3 values should be*
#
# ```
#  22,  102,  -83,
# ```
# And the length should be 1000.

# %% [markdown]
# At this point you have performed a transformation without my telling you exactly what to do. However, you got an answer. Assuming that you have gotten the first conversion right, to ensure that you understand the material, it is time to stop giving you the answers.

# %% [markdown]
# Reshape the array into a set of five columns with 200 rows.

# %% [markdown]
# Now that `ar` is a matrix, let's get the maximum and minimum values from the matrix. (Keep the value of `ar` to be the same). Be sure to remember, if you are getting the column maximums, how many total values you should be outputting.

# %% [markdown]
# Now that we have gotten the minimum and maximum values for the columns, get the mean of the entire matrix. (This should be a specific value.)

# %% [markdown]
# What is the total number of values that are less than the mean?

# %% [markdown]
# What is the total number of values in each row that are greater than this mean value? (Remember, if we are doing a row-oriented comparison, how many numbers should be in our output array?)

# %% [markdown]
# How many zeros are in the matrix that we have?

# %% [markdown]
# Lastly, sum all the values that are either greater than 100 or are less than 5 and greater than or equal to -20.
